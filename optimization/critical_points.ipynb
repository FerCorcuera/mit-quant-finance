# %% [markdown]
# # Plotting 3d functions to analyze their maximums and minimums

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-100, 100, 100)
y = np.linspace(-100, 100, 100)

X, Y = np.meshgrid(x, y)

R = X**2 - 4 * Y**2
Z = R

fig = plt.figure(figsize=(8, 6))
ax = plt.axes(projection="3d")

surface = ax.plot_surface(X, Y, Z, cmap="viridis", edgecolor="none")

ax.set_title("3D Function Plot: $Z = (\\sqrt{X^2 + Y^2})$")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
fig.colorbar(surface, ax=ax, shrink=0.5, aspect=10)


plt.show()

# %%
x = np.linspace(-100, 100, 100)
y = np.linspace(-100, 100, 100)

X, Y = np.meshgrid(x, y)

R = np.e ** (X**2 + Y**2)
Z = X * R

fig = plt.figure(figsize=(8, 6))
ax = plt.axes(projection="3d")

surface = ax.plot_surface(X, Y, Z, cmap="viridis", edgecolor="none")

ax.set_title("3D Function Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
fig.colorbar(surface, ax=ax, shrink=0.5, aspect=10)

plt.show()
# Out:
# /var/folders/1f/54wv342x795c_zyzqlgyjjkw0000gn/T/ipykernel_1508/4021012135.py:6: RuntimeWarning: overflow encountered in power
#   R = np.e**(X**2 + Y**2)

# %%
p = 0.6
var = 0.05
cov = p * np.sqrt(var) * np.sqrt(var)
cov
# Out:
# np.float64(0.029999999999999995)

# %%
c = np.array([[var, cov], [cov, var]])
iota = np.array([1, 2])
c_inv = np.linalg.inv(c)
(c_inv @ iota) / (iota.T @ c_inv @ iota)
# Out:
# array([-0.07692308,  0.53846154])

# %%
iota.T @ iota
# Out:
# np.int64(2)
